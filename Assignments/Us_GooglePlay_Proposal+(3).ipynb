# %% [markdown]
# # Google Play Store Applications
#
# #### Group members:
# - Omar M. Hussein.
# - Julian Ruggiero.
# - Eli Weiss.
#
#
# # 1.Introduction
#
# Google Play, formerly Android Market, is a digital distribution service operated and developed by Google. Google play is a place where people enjoy millions of the latest Android applications, games, music, movies, TV and books all over the world. You can find just about anything you need from time trackers for your office to games for your kids. You simply need to log in to your Google account to start purchasing applications on your mobile device. In this project we are going to closely examine the google play store, mainly focusing on the applications and what makes a successful application.
#
#
# # 2. Motivation.
#
# The 2010s were a decade of massive transformation for the tech industry. Advances in technology brought nearly every industry online, and the proliferation of mobile devices and social media fundamentally changed the way consumers and businesses interact. The top companies in the world are technology based companies even if they work on multiple things at once but more or less all of them have a strong online presence. Giants like Facebook, snapchat, twitter and google are all software companies and due to this high degree of success we want to really understand what makes a "successful" application. So here we endeavor to understand the market needs and the market demands as we dream of creating our own application someday. So really The Play store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. The image below illustrates the point that most successful companies are technology based and supports our previous premise about the importance of having a strong online presence.[5]
#
#
# # 3.Research Question
#
# We believe that the Key performance indicator to whether our application is doing well or not is the number of installs and for this particular reason our research question(s) is going to be revolving around this focal point that is the number of installs. Here we only have one research question and the reason we have only one research question is because we believe that it includes a set of questions that will be helpful for analysis such as what makes a good application? and how can we get people to download our application?
#
# - How do we maximize the amount of installs for our potential application?
# - How many installs will an application have?
#
# ![image.png](attachment:image.png)
#
# # 4. Data
#
# This information is scraped from the Google Play Store. This app information would not be available without it. However the person who scrapped the data put it in a Kaggle in the form of files. The data includes two csv files and text file. The dataset includes 18 features divided into 15 categorical/String and the rest is numerical. The dataset size is 9 megabytes.

# %% [markdown]
# # 5. Approach
#
#  - We are going to load the data to github and then load it from there into a Pandas data frame.
#
#  - Perform EDA work, as necessary.
#      - we will create bar charts, histograms and other graphics to further understand the nature of the data.
#
#  - Perform any required data preparation work, including any feature engineering adjustments you deem necessary for your work.
#
#  - Apply feature selection and/or dimensionality reduction techniques to identify explanatory variables for inclusion within our models. we may select the features manually via the application of domain knowledge, use forward or backward selection, or use a different feature selection method. It all depends on the nature of the data and how we are going to approach it.
#
#  - After training your various models, decide how you will select the “best” is.
#
#  - We will create an ensemble model.
#
#  - Interpret our results and provide conclusions.
#
# Since there are 15 categorical variables out of the 18 then we are likely to choose machine learning models that are popular when the input are categorical, a prime example on this is random forests and XGBOOST, we will also be performing some regression analysis.
#
# - The specifics of the model
#     - Random forests or random decision forests are an ensemble learning method for classification, regression and other tasks that operate by constructing a multitude of decision trees at training time and outputting the class that is the mode of the classes (classification) or mean prediction (regression) of the individual trees.
#
#     - XGBOOST this is an ensemble method that seeks to create a strong classifier (model) based on “weak” classifiers. This is supported for both regression and classification problems. XGBoost specifically, implements this algorithm for decision tree boosting with an additional custom regularization term in the objective.
#
#     - Support vector machine are supervised learning models with associated learning algorithms that analyze data used for classification and regression analysis.
#
# Finally we would combine all the models into one ensemble model for the purposes of prediction. We will get the mean value of all the models.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Finally we would provide conclusion/guidelines based on the information acquired.

# %% [markdown]
# # Refrences
#
# [1]https://www.kaggle.com/lava18/google-play-store-apps
#
# [2]https://www.visualcapitalist.com/biggest-tech-companies-market-cap-23-years/
#
# [3] https://en.wikipedia.org/wiki/Random_forest#:~:text=Random%20forests%20or%20random%20decision,prediction%20(regression)%20of%20the%20individual
#
# [4]https://xgboost.readthedocs.io/en/latest/
#
# [5] https://www.visualcapitalist.com/biggest-tech-companies-market-cap-23-years/
#
#
#
# ##### Thanks from Omar, Julian and Eli.
